# %% [markdown]
# # **🧠 Redução de Dimensionalidade em Imagens para Redes Neurais**
#
# Este projeto demonstra como reduzir a complexidade de imagens para uso em redes neurais. A imagem colorida é convertida para escala de cinza e, em seguida, binarizada (preto e branco), simplificando os dados visuais.
#
# Essas transformações facilitam o processamento pelas redes neurais, pois eliminam informações desnecessárias e reduzem a dimensionalidade da entrada, tornando o treinamento mais eficiente.

# %% [markdown]
# **✅ Passo 1 – Importar as bibliotecas no Python**
#
# Essas bibliotecas permitem carregar, processar e exibir imagens. cv2 é do OpenCV e matplotlib.pyplot serve para mostrar imagens no Jupyter ou Colab.

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ✅ **Passo 2 – Carregar a imagem**
#
# Aqui você carrega uma imagem colorida do seu computador. O OpenCV vai ler no formato BGR (azul, verde, vermelho).

# %%
# Lê a imagem colorida
imagem_colorida = cv2.imread("imagem.png")  # substitua pelo nome da sua imagem

# %% [markdown]
# ✅ **Passo 3 – Converter para escala de cinza**
#
# Essa conversão transforma a imagem colorida em tons de cinza (de 0 a 255), usando uma média ponderada das cores RGB.

# %%
# Converte para escala de cinza
imagem_cinza = cv2.cvtColor(imagem_colorida, cv2.COLOR_BGR2GRAY)

# %% [markdown]
# ✅ **Passo 4 – Aplicar binarização (Preto e Branco)**
#
# A imagem cinza é transformada em preto e branco com base em um valor de corte (limiar). Pixels acima do limiar viram branco (255), os demais viram preto (0).

# %%
# Define o limiar (threshold) para binarização
limiar = 127

# Aplica binarização: pixels acima do limiar viram 255, abaixo viram 0
_, imagem_binarizada = cv2.threshold(imagem_cinza, limiar, 255, cv2.THRESH_BINARY)

# %% [markdown]
# ✅ **Passo 5 – Exibir os resultados**
#
# Esse trecho exibe as três versões da imagem: original, em tons de cinza e binarizada. Convertemos de BGR para RGB só para mostrar corretamente no Matplotlib.

# %%
# Converte imagem colorida para RGB só para exibição correta com matplotlib
imagem_rgb = cv2.cvtColor(imagem_colorida, cv2.COLOR_BGR2RGB)

# Exibe as três imagens lado a lado
plt.figure(figsize=(15,5))

plt.subplot(1, 3, 1)
plt.title("Imagem Colorida")
plt.imshow(imagem_rgb)
plt.axis('off')

plt.subplot(1, 3, 2)
plt.title("Escala de Cinza")
plt.imshow(imagem_cinza, cmap='gray')
plt.axis('off')

plt.subplot(1, 3, 3)
plt.title("Imagem Binarizada")
plt.imshow(imagem_binarizada, cmap='gray')
plt.axis('off')

plt.tight_layout()
plt.show()
